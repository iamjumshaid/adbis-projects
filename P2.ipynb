# %%
import pandas as pd
import hashlib
import numpy
import os

pd.set_option('display.max_rows', 200)

# %% [markdown]
# # Task 1

# %%
df = pd.read_csv('100k.txt', sep='\t', header=None, names=['Subject', 'Property','Object'])
df['Object'] = df.Object.str.rstrip(" .")
# df

# %%
df["Property"] = df.Property.str.split(":").apply(lambda x: x[1])
df["Object"] = df.Object.str.split(":").apply(lambda x: x[1] if len(x)>1 else x[0])
df["Subject"] = df.Subject.str.split(":").apply(lambda x: x[1])

# %%
property_dicts = {}
for prop, df_part in df.groupby('Property'):
    print(prop)
    print(df_part.head(2))
    print("========================")
    property_dicts[prop] = df_part[["Subject","Object"]]
# Out:
# Location
#     Subject  Property   Object
# 281   User3  Location  City215
# 404   User4  Location    City2
# ========================
# actor
#          Subject Property Object
# 95279  Product19    actor  User3
# 95280  Product19    actor  User5
# ========================
# age
#     Subject Property     Object
# 46    User1      age  AgeGroup5
# 673   User7      age  AgeGroup5
# ========================
# aggregateRating
#          Subject         Property Object
# 96924  Retailer0  aggregateRating      4
# 97230  Retailer3  aggregateRating      4
# ========================
# artist
#          Subject Property   Object
# 94720   Product3   artist  User114
# 96024  Product59   artist  User731
# ========================
# author
#         Subject Property   Object
# 94760  Product6   author   User90
# 94761  Product6   author  User175
# ========================
# award
#          Subject Property                                             Object
# 96523  Product77    award                                           Dniester
# 96645  Product83    award  power killdeer deodorant voiceless codeine too...
# ========================
# birthDate
#      Subject   Property      Object
# 1007   User9  birthDate  1974-02-09
# 1493  User12  birthDate  1993-02-24
# ========================
# bookEdition
#          Subject     Property Object
# 95586  Product33  bookEdition      4
# 96093  Product63  bookEdition      4
# ========================
# caption
#          Subject Property                                             Object
# 95789  Product49  caption  ungratefulness's Tuscaloosa's specimen's admin...
# 95950  Product56  caption     jeremiad surrealistic extrusion drubs hookah's
# ========================
# composer
#            Subject  Property  Object
# 95184    Product14  composer  BONNIE
# 101122  Product119  composer   CESAR
# ========================
# conductor
#            Subject   Property   Object
# 96707    Product86  conductor  User362
# 101119  Product119  conductor  User347
# ========================
# contactPoint
#          Subject      Property   Object
# 97229  Retailer3  contactPoint  User385
# 97344  Retailer4  contactPoint  User111
# ========================
# contentRating
#         Subject       Property Object
# 94690  Product2  contentRating     12
# 94765  Product6  contentRating     12
# ========================
# contentSize
#         Subject     Property Object
# 94682  Product1  contentSize   4993
# 94776  Product7  contentSize   8502
# ========================
# datePublished
#          Subject       Property      Object
# 95644  Product38  datePublished  1983-07-25
# 95880  Product51  datePublished  2004-12-27
# ========================
# description
#         Subject     Property  \
# 94620  Product0  description
# 94683  Product1  description
#
#                                                   Object
# 94620  differed charwoman's Spitz's inciting Thanksgi...
# 94683  Goya anteater slash retraction's nighthawks re...
# ========================
# director
#          Subject  Property   Object
# 95149  Product11  director  User190
# 95290  Product19  director  User987
# ========================
# duration
#            Subject  Property Object
# 95632    Product37  duration     54
# 102807  Product201  duration      7
# ========================
# editor
#          Subject Property   Object
# 95528  Product29   editor  User889
# 95529  Product29   editor  User890
# ========================
# eligibleQuantity
#      Subject          Property Object
# 1201  Offer0  eligibleQuantity      8
# 1207  Offer1  eligibleQuantity      2
# ========================
# eligibleRegion
#      Subject        Property    Object
# 1205  Offer1  eligibleRegion  Country0
# 1206  Offer1  eligibleRegion  Country6
# ========================
# email
#    Subject Property                                             Object
# 10   User0    email                     waxed singles monarchic sass's
# 45   User1    email  shooing file censor's missile's forwarding con...
# ========================
# employee
#          Subject  Property   Object
# 97143  Retailer2  employee  User486
# 97144  Retailer2  employee  User567
# ========================
# expires
#          Subject Property      Object
# 95683  Product41  expires  2017-04-26
# 96372  Product72  expires  2018-04-01
# ========================
# familyName
#     Subject    Property Object
# 108   User2  familyName   LEAH
# 280   User3  familyName  MICAH
# ========================
# faxNumber
#          Subject   Property   Object
# 97341  Retailer4  faxNumber  9583297
# ========================
# follows
#    Subject Property  Object
# 12   User0  follows  User24
# 13   User0  follows  User27
# ========================
# friendOf
#     Subject  Property Object
# 169   User2  friendOf  User7
# 170   User2  friendOf  User8
# ========================
# gender
#     Subject Property   Object
# 405   User4   gender  Gender1
# 609   User6   gender  Gender1
# ========================
# givenName
#     Subject   Property Object
# 107   User2  givenName  BERTA
# 279   User3  givenName  WANDA
# ========================
# hasGenre
#         Subject  Property      Object
# 94660  Product0  hasGenre  SubGenre69
# 94661  Product0  hasGenre  SubGenre70
# ========================
# hasReview
#         Subject   Property    Object
# 94621  Product0  hasReview  Review24
# 94622  Product0  hasReview  Review48
# ========================
# hits
#         Subject Property Object
# 95104  Website0     hits   8105
# 95107  Website1     hits   8460
# ========================
# homepage
#      Subject  Property     Object
# 827    User8  homepage   Website1
# 2801  User29  homepage  Website43
# ========================
# includes
#      Subject  Property      Object
# 1203  Offer0  includes  Product210
# 1209  Offer1  includes  Product200
# ========================
# isbn
#          Subject Property Object
# 94758   Product6     isbn  50543
# 95377  Product25     isbn  23701
# ========================
# jobTitle
#      Subject  Property                                             Object
# 825    User8  jobTitle  flyer covetousness's wright stagnated habitu  ...
# 1891  User16  jobTitle                                 blushers uppercase
# ========================
# keywords
#          Subject  Property                                             Object
# 94619   Product0  keywords                                    Amiga's Jakarta
# 95141  Product10  keywords  honeying secluding outset vernacular's gel ste...
# ========================
# language
#         Subject  Property     Object
# 95103  Website0  language  Language3
# 95106  Website1  language  Language0
# ========================
# legalName
#          Subject   Property                                             Object
# 97342  Retailer4  legalName  perdition's needlessly doodler's Rachel postul...
# ========================
# likes
#     Subject Property     Object
# 594   User6    likes  Product12
# 595   User6    likes  Product20
# ========================
# makesPurchase
#    Subject       Property       Object
# 38   User0  makesPurchase  Purchase132
# 39   User0  makesPurchase  Purchase277
# ========================
# movement
#          Subject  Property Object
# 95203  Product15  movement      4
# 96706  Product86  movement      7
# ========================
# name
#          Subject Property                                             Object
# 96926  Retailer0     name  intervening coinage's monolingual thermal's fo...
# 97055  Retailer1     name  cahoots handfuls monosyllable's troughs Toyota...
# ========================
# nationality
#     Subject     Property    Object
# 278   User3  nationality  Country9
# 826   User8  nationality  Country2
# ========================
# numberOfPages
#          Subject       Property Object
# 95697  Product42  numberOfPages    518
# 95706  Product43  numberOfPages    767
# ========================
# offers
#          Subject Property  Object
# 96927  Retailer0   offers  Offer0
# 96928  Retailer0   offers  Offer1
# ========================
# openingHours
#          Subject      Property Object
# 96923  Retailer0  openingHours     10
# 97054  Retailer1  openingHours     11
# ========================
# opus
#          Subject Property Object
# 95202  Product15     opus    338
# 96705  Product86     opus     90
# ========================
# parentCountry
#   Subject       Property     Object
# 0   City0  parentCountry  Country20
# 1   City1  parentCountry   Country0
# ========================
# paymentAccepted
#          Subject         Property  \
# 96925  Retailer0  paymentAccepted
# 97146  Retailer2  paymentAccepted
#
#                                                   Object
# 96925  oboists pimientos underling whirligig's catbir...
# 97146                              repelled lovemaking's
# ========================
# performed_in
#            Subject      Property Object
# 101121  Product119  performed_in  City5
# ========================
# performer
#            Subject   Property  \
# 96708    Product86  performer
# 101120  Product119  performer
#
#                                                    Object
# 96708   schizoid sleepwalkers Paula's Caracalla lifeli...
# 101120  spend alternate reindeer Mimosa's priors milli...
# ========================
# price
#      Subject Property Object
# 1202  Offer0    price    606
# 1208  Offer1    price    128
# ========================
# priceValidUntil
#      Subject         Property      Object
# 1217  Offer3  priceValidUntil  2013-07-30
# 1224  Offer4  priceValidUntil  2013-08-22
# ========================
# printColumn
#            Subject     Property Object
# 95896    Product53  printColumn   1981
# 101430  Product130  printColumn   2001
# ========================
# printEdition
#            Subject      Property Object
# 95897    Product53  printEdition     33
# 101431  Product130  printEdition     11
# ========================
# printPage
#          Subject   Property Object
# 95877  Product51  printPage    835
# 96062  Product61  printPage    889
# ========================
# printSection
#          Subject      Property Object
# 95879  Product51  printSection      9
# 96067  Product61  printSection      7
# ========================
# producer
#          Subject  Property                                             Object
# 94721   Product3  producer  amebae Byelorussia's mitosis's omnivores Plata...
# 95153  Product11  producer             Berkeley Andres dissatisfy graveyard's
# ========================
# publisher
#          Subject   Property                                             Object
# 95320  Product22  publisher                                  beanbag Hollywood
# 95608  Product35  publisher  tweed's Talleyrand's Hittite puts backgammon L...
# ========================
# purchaseDate
#          Subject      Property      Object
# 96903  Purchase1  purchaseDate  2012-11-30
# 96906  Purchase2  purchaseDate  2012-06-06
# ========================
# purchaseFor
#          Subject     Property     Object
# 96900  Purchase0  purchaseFor   Product0
# 96902  Purchase1  purchaseFor  Product12
# ========================
# rating
#       Subject Property Object
# 9798  Review0   rating      5
# 9801  Review1   rating      2
# ========================
# record_number
#          Subject       Property Object
# 94722   Product3  record_number    987
# 96026  Product59  record_number    950
# ========================
# release
#          Subject Property      Object
# 96045  Product60  release  1995-07-12
# 96112  Product64  release  1982-10-21
# ========================
# reviewer
#       Subject  Property   Object
# 9799  Review0  reviewer  User427
# 9802  Review1  reviewer   User65
# ========================
# serialNumber
#      Subject      Property    Object
# 1204  Offer0  serialNumber  76197646
# 1211  Offer1  serialNumber  75186653
# ========================
# subscribes
#     Subject    Property    Object
# 268   User2  subscribes  Website4
# 269   User2  subscribes  Website6
# ========================
# tag
#         Subject Property    Object
# 94615  Product0      tag    Topic3
# 94616  Product0      tag  Topic193
# ========================
# telephone
#      Subject   Property   Object
# 3050  User33  telephone  6874265
# 3239  User38  telephone  9850579
# ========================
# text
#       Subject Property                                             Object
# 9797  Review0     text  brawls campaigner's Chuck's deescalate splendi...
# 9800  Review1     text                                      cottonmouth's
# ========================
# title
#       Subject Property                                             Object
# 9809  Review4    title  Florine's amputee's reminiscence's tumbleweeds...
# 9818  Review7    title  Clem perspicuity's flatirons Tabatha immensity...
# ========================
# totalVotes
#         Subject    Property Object
# 94850  Review18  totalVotes    611
# 94863  Review22  totalVotes    504
# ========================
# trailer
#          Subject Property     Object
# 96524  Product77  trailer  Website29
# 96646  Product83  trailer   Website5
# ========================
# type
#    Subject Property Object
# 37   User0     type  Role0
# 96   User1     type  Role0
# ========================
# url
#         Subject Property                                             Object
# 95102  Website0      url  shrub's Brahmins porterhouse's communions rese...
# 95105  Website1      url  hoedown marbling streams advert's Antofagasta ...
# ========================
# userId
#    Subject Property   Object
# 11   User0   userId  1806723
# 47   User1   userId  8951611
# ========================
# validFrom
#      Subject   Property      Object
# 1210  Offer1  validFrom  2013-06-16
# 1215  Offer2  validFrom  2013-04-07
# ========================
# validThrough
#      Subject      Property      Object
# 1223  Offer3  validThrough  2013-11-11
# 1234  Offer5  validThrough  2013-10-25
# ========================
# wordCount
#          Subject   Property Object
# 96064  Product61  wordCount   3507
# 96441  Product73  wordCount   3492
# ========================

# %%
numeric_objects = []
for k_prop in property_dicts.keys():
    if property_dicts[k_prop]['Object'].str.isnumeric().all():
        numeric_objects.append(k_prop)
        property_dicts[k_prop]['Object'] = property_dicts[k_prop]['Object'].apply(lambda x: int(x))
# Out:
# /var/folders/t4/sp85qyw93319q2vj6jvsjg2r0000gp/T/ipykernel_35111/2289272882.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_dicts[k_prop]['Object'] = property_dicts[k_prop]['Object'].apply(lambda x: int(x))

# %%
numeric_objects
# Out:
# ['aggregateRating',
#  'bookEdition',
#  'contentRating',
#  'contentSize',
#  'duration',
#  'eligibleQuantity',
#  'faxNumber',
#  'hits',
#  'isbn',
#  'movement',
#  'numberOfPages',
#  'openingHours',
#  'opus',
#  'price',
#  'printColumn',
#  'printEdition',
#  'printPage',
#  'printSection',
#  'rating',
#  'record_number',
#  'serialNumber',
#  'telephone',
#  'totalVotes',
#  'userId',
#  'wordCount']

# %%
# so for each user he has an id

df[df.Subject.apply(lambda x: x[:4] == "User")].Subject.nunique()
# Out:
# 1000

# %%
property_dicts['userId'].Subject.nunique()
# Out:
# 1000

# %%
user_ID_mapping = dict(property_dicts['userId'].values)
user_ID_mapping['User0']
# Out:
# 1806723

# %%
# so we can fill the user with the user id
user_properties = []
user_dual_properties = []

for k_prop in property_dicts.keys():
    if property_dicts[k_prop]['Subject'].apply(lambda x: x[:4] == "User").all():
        if k_prop == "userId":
            print(k_prop)
            continue
        user_properties.append(k_prop)
        property_dicts[k_prop]['Subject'] = property_dicts[k_prop]['Subject']\
                    .apply(lambda x: user_ID_mapping[x])
        if property_dicts[k_prop]['Object'].apply(lambda x: x[:4] == "User").all():
            user_dual_properties.append(k_prop)
            property_dicts[k_prop]['Object'] = property_dicts[k_prop]['Object']\
                    .apply(lambda x: user_ID_mapping[x])
# Out:
# userId

# %%
property_dicts['follows']
# Out:
#        Subject   Object
# 12     1806723  2680384
# 13     1806723  2211675
# 14     1806723  5335024
# 15     1806723  2915528
# 16     1806723  2004500
# ...        ...      ...
# 88905  3143980  1986609
# 88906  3143980  5131970
# 88907  3143980  1358408
# 88908  3143980  1661104
# 88909  3143980  7497008
#
# [31887 rows x 2 columns]

# %%
user_properties
# Out:
# ['Location',
#  'age',
#  'birthDate',
#  'familyName',
#  'follows',
#  'friendOf',
#  'gender',
#  'givenName',
#  'jobTitle',
#  'likes',
#  'makesPurchase',
#  'nationality',
#  'subscribes']

# %%
user_dual_properties
# Out:
# ['follows', 'friendOf']

# %%
for _, row in property_dicts['follows'].iterrows():
    print(row.index)
    break
# Out:
# Index(['Subject', 'Object'], dtype='object')

# %% [markdown]
# # Task 2

# %% [markdown]
# **Hash join**

# %%
def partition(table, join_key, hash_function):
    table['hash_key'] = table[join_key].apply(hash_function)
    hash_table = dict(tuple(table.groupby('hash_key')))
    table.drop('hash_key', axis=1, inplace=True)
    return hash_table


def probe(hash_table, join_key1, table2, join_key2, hash_function):
    dfs_to_join = []
    for _, row in table2.iterrows():
        hash_key = hash_function(row[join_key2])
        if hash_key in hash_table:
            df_hash = hash_table[hash_key].copy()
            df_hash = df_hash[df_hash[join_key1] == row[join_key2]]
            for col in row.index:
                df_hash[col + '_2'] = row[col]
            dfs_to_join.append(df_hash)
    joined_tables = pd.concat(dfs_to_join,axis=0)
    return joined_tables

def hash_join(table1, table2, join_key1, join_key2, hash_function=hash, join_type='inner'):

    if join_type == 'right':
        temp = table1
        table1 = table2
        table2 = temp
        temp_key = join_key1
        join_key1 = join_key2
        join_key2 = temp_key
    
    hash_table = partition(table1, join_key1, hash_function)
    joint = probe(hash_table, join_key1, table2, join_key2, hash_function).drop('hash_key', axis=1)
    
    if join_type in ['right', 'left']:
        return pd.concat([joint, table1[~table1[join_key1].apply(lambda x: x in joint[join_key1].values)]],axis=0)
    
    return joint

# %%
hash_join(property_dicts['Location'], property_dicts['parentCountry'],'Object','Subject',join_type='inner').sort_values('Object')
# Out:
#        Subject  Object Subject_2   Object_2
# 1771   8163087   City0     City0  Country20
# 54114  4217937   City0     City0  Country20
# 55056  2040846   City0     City0  Country20
# 57123  2225099   City0     City0  Country20
# 57851  2796600   City0     City0  Country20
# ...        ...     ...       ...        ...
# 46840  7896679  City94    City94   Country3
# 60268  2140616  City94    City94   Country3
# 33210  4055499  City94    City94   Country3
# 41594  2479861  City96    City96   Country1
# 67539  4177550  City98    City98   Country5
#
# [387 rows x 4 columns]

# %% [markdown]
# **Sort-merge join**

# %%
def sort_merge_join(table1, table2, join_key1, join_key2,join_type='inner'):

    if join_type == 'right':
        temp = table1
        table1 = table2
        table2 = temp
        temp_key = join_key1
        join_key1 = join_key2
        join_key2 = temp_key

    sorted_table1 = table1.sort_values(join_key1)
    sorted_table2 = table2.sort_values(join_key2)
    
    pointer1 = 0 
    pointer2 = 0
    result = []
    
    while True:
        condition1 = pointer1 < len(sorted_table1) 
        condition2 = pointer2 < len(sorted_table2)
        
        if join_type=='inner' and not (condition1 and condition2):
            break
        
        if join_type in ['right','left']:
            if condition1 and not condition2:
                table1_remaining = sorted_table1[~sorted_table1[join_key1].isin(table2.sort_values(join_key2))]
                indices, rowSeries = zip(*table1_remaining.add_suffix('_1').iterrows())
                result.extend(list(rowSeries))
                break
            elif not condition1:
                break
        
        value1 = sorted_table1.iloc[pointer1][join_key1]
        value2 = sorted_table2.iloc[pointer2][join_key2]

        if value1 == value2:
            result.append(pd.concat([sorted_table1.iloc[pointer1].add_suffix('_1'), sorted_table2.iloc[pointer2].add_suffix('_2')]))
            
            skip_condition1 = (pointer2 < len(sorted_table2)-1) and (sorted_table2.iloc[pointer2+1][join_key2] != value2)
            skip_condition2 = (pointer1 < len(sorted_table1)-1) and (sorted_table1.iloc[pointer1+1][join_key1] != value1)
            
            if skip_condition1:
                pointer1 += 1
            if skip_condition2:
                pointer2 += 1
                
        elif value1 < value2:
                pointer1 += 1
        else:
                pointer2 += 1
#     print(result[0])
#     print(result[-1])
    return pd.DataFrame(result)

# %%
merged = sort_merge_join(property_dicts['Location'], property_dicts['parentCountry'],'Object','Subject',join_type='inner')

# %%
merged
# Out:
#      Subject_1 Object_1 Subject_2   Object_2
# 0      1548262    City0     City0  Country20
# 1      9278057    City0     City0  Country20
# 2      5797591    City0     City0  Country20
# 3      4303655    City0     City0  Country20
# 4      9291031    City0     City0  Country20
# ..         ...      ...       ...        ...
# 382    7896679   City94    City94   Country3
# 383    2140616   City94    City94   Country3
# 384    4055499   City94    City94   Country3
# 385    2479861   City96    City96   Country1
# 386    4177550   City98    City98   Country5
#
# [387 rows x 4 columns]

# %%
indices, rowSeries =zip(*(property_dicts['Location'].sort_values('Object').iloc[96:98]).iterrows())
rowSeries
# Out:
# (Subject    4810084
#  Object     City106
#  Name: 44024, dtype: object,
#  Subject    1890641
#  Object     City109
#  Name: 3155, dtype: object)

# %%
property_dicts['parentCountry'].sort_values('Subject').iloc[10:13]
# Out:
#       Subject     Object
# 9073  City107   Country2
# 9074  City108   Country1
# 9075  City109  Country17

# %%
hashed = hash_join(property_dicts['Location'], property_dicts['parentCountry'],'Object','Subject',join_type='inner')
merged = sort_merge_join(property_dicts['Location'], property_dicts['parentCountry'],'Object','Subject',join_type='inner')
(~hashed['Subject'].isin(merged[0])).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 3
#       1 hashed = hash_join(property_dicts['Location'], property_dicts['parentCountry'],'Object','Subject',join_type='inner')
#       2 merged = sort_merge_join(property_dicts['Location'], property_dicts['parentCountry'],'Object','Subject',join_type='inner')
# ----> 3 (~hashed['Subject'].isin(merged[0])).sum()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
missing = hashed[(~hashed['Subject'].isin(merged[0]))]
missing

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Task 1 with 'watdiv.10M.nt' Big Data File

# %%
# we read the data in batch of 100. so the memory is never overflooded regardless of the data size.
# also, after reading the data, we make one file for each property and neglect all the other properties
# that are not necessary to save memory size and processing time.

file_path = 'watdiv.10M.nt'
batch_size = 100
file_path_follows = 'follows.txt'
file_path_friendOf = 'friendOf.txt'
file_path_likes = 'likes.txt'
file_path_hasReview = 'hasReview.txt'

# Function to delete a file if it exists
def delete_if_exists(file_path):
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"Deleted '{file_path}'.")
    else:
        print(f"'{file_path}' does not exist.")

# Delete the files if they exist
delete_if_exists(file_path_follows)
delete_if_exists(file_path_friendOf)
delete_if_exists(file_path_likes)
delete_if_exists(file_path_hasReview)


# Read the file in chunks using pd.read_csv() and process each chunk
# No need to extract the property in seperated files
# Because we have each seperate file for each property type
for df_chunk in pd.read_csv(file_path, chunksize=batch_size, sep='\t', header=None, names=['Subject', 'Property', 'Object']):
    df_chunk['Property'] = df_chunk['Property'].str.extract(r'[#/]([^#/>]+)>\s*$')
    filtered_df = df_chunk.loc[df_chunk['Property'].str.contains('follows|friendOf|likes|hasReview')]
    if len(filtered_df):
        if (filtered_df['Property'] == 'follows').sum():
            filtered_df[filtered_df['Property'] == 'follows'][['Subject', 'Object']].to_csv(file_path_follows, mode='a', index=False, header=False)
        
        if (filtered_df['Property'] == 'friendOf').sum():
            filtered_df[filtered_df['Property'] == 'friendOf'][['Subject', 'Object']].to_csv(file_path_friendOf, mode='a', index=False, header=False)
        
        if (filtered_df['Property'] == 'likes').sum():
            filtered_df[filtered_df['Property'] == 'likes'][['Subject', 'Object']].to_csv(file_path_likes, mode='a', index=False, header=False)
        
        if (filtered_df['Property'] == 'hasReview').sum():
            filtered_df[filtered_df['Property'] == 'hasReview'][['Subject', 'Object']].to_csv(file_path_hasReview, mode='a', index=False, header=False)
# Out:
# Deleted 'follows.txt'.
# Deleted 'friendOf.txt'.
# Deleted 'likes.txt'.
# Deleted 'hasReview.txt'.

# %%
list_of_dfs = ['follows', 'friendOf', 'likes', 'hasReview']
property_dicts = {}

for prop in list_of_dfs:
    property_dicts[prop] = pd.read_csv(f'{prop}.txt', header=None, names=['Subject','Object'])
    property_dicts[prop]['Object'] = property_dicts[prop].Object.str.rstrip(" .")
    property_dicts[prop]['Object'] = property_dicts[prop]['Object'].str.extract(r'[#/]([^#/>]+)>\s*$')
    property_dicts[prop]['Subject'] = property_dicts[prop]['Subject'].str.extract(r'[#/]([^#/>]+)>\s*$')

property_dicts['follows']
# Out:
#            Subject     Object
# 0        User10000  User10146
# 1        User10000  User12191
# 2        User10000  User13638
# 3        User10000  User15527
# 4        User10000  User15778
# ...            ...        ...
# 3289302      User9  User26462
# 3289303      User9  User30532
# 3289304      User9  User51126
# 3289305      User9  User90573
# 3289306      User9  User98575
#
# [3289307 rows x 2 columns]

# %%
property_dicts = {}
for prop, df_part in df.groupby('Property'):
    print(prop)
    print(df_part.head(2))
    print("========================")
    property_dicts[prop] = df_part[["Subject","Object"]]
